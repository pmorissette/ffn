# %%
import ffn
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# download price data from Yahoo! Finance. By default, 
# the Adj. Close will be used. 
prices = ffn.get('aapl,msft', start='2010-01-01')

# %%
# let's compare the relative performance of each stock 
# we will rebase here to get a common starting point for both securities
ax = prices.rebase().plot()

# %%
# now what do the return distributions look like?
returns = prices.to_returns().dropna()
ax = returns.hist(figsize(10, 5))

# %%
# ok now what about some performance metrics?
stats = prices.calc_stats()
stats.display()
# Out:
# Stat                 aapl        msft
# -------------------  ----------  ----------
# Start                2010-01-04  2010-01-04
# End                  2014-06-24  2014-06-24
#
# Total Return         208.97%     51.93%
# Daily Sharpe         1.06        0.53
# CAGR                 28.72%      9.81%
# Max Drawdown         -43.80%     -26.36%
#
# MTD                  -0.17%      1.98%
# 3m                   17.86%      3.80%
# 6m                   12.61%      14.23%
# YTD                  13.95%      13.24%
# 1Y                   60.78%      27.48%
# 3Y (ann.)            26.53%      23.24%
# 5Y (ann.)            28.72%      9.81%
# 10Y (ann.)           28.72%      9.81%
# Since Incep. (ann.)  28.72%      9.81%
#
# Daily Sharpe         1.06        0.53
# Daily Mean (ann.)    29.02%      11.91%
# Daily Vol (ann.)     27.32%      22.52%
# Daily Skew           -0.12       -0.21
# Daily Kurt           4.77        5.22
# Best Day             8.88%       7.29%
# Worst Day            -12.36%     -11.39%
#
# Monthly Sharpe       1.22        0.65
# Monthly Mean (ann.)  31.51%      13.89%
# Monthly Vol (ann.)   25.75%      21.41%
# Monthly Skew         0.01        -0.08
# Monthly Kurt         -0.08       0.24
# Best Month           18.84%      15.69%
# Worst Month          -14.40%     -15.12%
#
# Yearly Sharpe        1.81        0.70
# Yearly Mean          20.04%      14.71%
# Yearly Vol           11.07%      21.03%
# Yearly Skew          0.10        1.30
# Yearly Kurt          -2.98       2.01
# Best Year            32.57%      44.31%
# Worst Year           8.08%       -4.51%
#
# Avg. Drawdown        -4.47%      -3.89%
# Avg. Drawdown Days   31.57       50.48
# Avg. Up Month        6.92%       5.25%
# Avg. Down Month      -4.46%      -4.61%
# Win Year %           100.00%     75.00%
# Win 12m %            76.74%      76.74%

# %%
# what about the drawdowns?
ax = stats.prices.to_drawdown_series().plot()
